# %%
import pandas as pd

# %%
# 데이터셋 경로, 파일명 설정 및 csv 파일 읽기

# dataset_dir = './#dataset/5criminal_occur_arr/'
# filename = dataset_dir + '2001'
# df = pd.read_csv(filename + '.csv', encoding='euc-kr')

# %%
# 데이터셋에 date 컬럼 추가 및 날짜형식으로 변경

# df['date'] = '2001'
# df['date'] = pd.to_datetime(df['date'])

# %%
# 정제한 데이터셋 재저장

# df.to_csv(filename+ '.csv', index=False)

# %%
dataset_dir = './dataset/'
df2000 = dataset_dir + '2000'
df2001 = dataset_dir + '2001'
df2002 = dataset_dir + '2002'
df2003 = dataset_dir + '2003'
df2004 = dataset_dir + '2004'
df2005 = dataset_dir + '2005'
df2006 = dataset_dir + '2006'
df2007 = dataset_dir + '2007'
df2008 = dataset_dir + '2008'
df2009 = dataset_dir + '2009'
df2010 = dataset_dir + '2010'
df2011 = dataset_dir + '2011'
df2012 = dataset_dir + '2012'
df2013 = dataset_dir + '2013'
df2014 = dataset_dir + '2014'
df2015 = dataset_dir + '2015'
df2016 = dataset_dir + '2016'
df2017 = dataset_dir + '2017'
df2018 = dataset_dir + '2018'

# %%
# df = pd.read_csv(df2018 + '.csv', encoding='euc-kr')

# %%
# df['date'] = '2018'
# df['date'] = pd.to_datetime(df['date'])

# %%
# df.to_csv(df2018 + '.csv', index=False)

# %%
# df
# Out:
#       구분  죄종 발생검거    건수       date
# 0     중부  살인   발생     1 2018-01-01
# 1     중부  살인   검거     1 2018-01-01
# 2     중부  강도   발생     5 2018-01-01
# 3     중부  강도   검거     7 2018-01-01
# 4     중부  강간   발생   132 2018-01-01
# 5     중부  강간   검거    63 2018-01-01
# 6     중부  절도   발생  1057 2018-01-01
# 7     중부  절도   검거   415 2018-01-01
# 8     중부  폭력   발생  1176 2018-01-01
# 9     중부  폭력   검거  1010 2018-01-01
# 10    종로  살인   발생     5 2018-01-01
# 11    종로  살인   검거     4 2018-01-01
# 12    종로  강도   발생     1 2018-01-01
# 13    종로  강도   검거     0 2018-01-01
# 14    종로  강간   발생   136 2018-01-01
# 15    종로  강간   검거   114 2018-01-01
# 16    종로  절도   발생   744 2018-01-01
# 17    종로  절도   검거   398 2018-01-01
# 18    종로  폭력   발생  1131 2018-01-01
# 19    종로  폭력   검거   993 2018-01-01
# 20   남대문  살인   발생     1 2018-01-01
# 21   남대문  살인   검거     1 2018-01-01
# 22   남대문  강도   발생     6 2018-01-01
# 23   남대문  강도   검거     4 2018-01-01
# 24   남대문  강간   발생    75 2018-01-01
# 25   남대문  강간   검거    52 2018-01-01
# 26   남대문  절도   발생   798 2018-01-01
# 27   남대문  절도   검거   417 2018-01-01
# 28   남대문  폭력   발생   779 2018-01-01
# 29   남대문  폭력   검거   709 2018-01-01
# ..   ...  ..  ...   ...        ...
# 280   은평  살인   발생     4 2018-01-01
# 281   은평  살인   검거     4 2018-01-01
# 282   은평  강도   발생     1 2018-01-01
# 283   은평  강도   검거     1 2018-01-01
# 284   은평  강간   발생   130 2018-01-01
# 285   은평  강간   검거   117 2018-01-01
# 286   은평  절도   발생   773 2018-01-01
# 287   은평  절도   검거   491 2018-01-01
# 288   은평  폭력   발생  1308 2018-01-01
# 289   은평  폭력   검거  1158 2018-01-01
# 290   도봉  살인   발생     1 2018-01-01
# 291   도봉  살인   검거     1 2018-01-01
# 292   도봉  강도   발생     5 2018-01-01
# 293   도봉  강도   검거     3 2018-01-01
# 294   도봉  강간   발생   113 2018-01-01
# 295   도봉  강간   검거   117 2018-01-01
# 296   도봉  절도   발생   781 2018-01-01
# 297   도봉  절도   검거   431 2018-01-01
# 298   도봉  폭력   발생  1349 2018-01-01
# 299   도봉  폭력   검거  1124 2018-01-01
# 300   수서  살인   발생     5 2018-01-01
# 301   수서  살인   검거     5 2018-01-01
# 302   수서  강도   발생     5 2018-01-01
# 303   수서  강도   검거     2 2018-01-01
# 304   수서  강간   발생   194 2018-01-01
# 305   수서  강간   검거   171 2018-01-01
# 306   수서  절도   발생   984 2018-01-01
# 307   수서  절도   검거   481 2018-01-01
# 308   수서  폭력   발생  1697 2018-01-01
# 309   수서  폭력   검거  1443 2018-01-01
#
# [310 rows x 5 columns]

# %%
csv2000 = pd.read_csv(df2000 + '.csv')
csv2001 = pd.read_csv(df2001 + '.csv')
csv2002 = pd.read_csv(df2002 + '.csv')
csv2003 = pd.read_csv(df2003 + '.csv')
csv2004 = pd.read_csv(df2004 + '.csv')
csv2005 = pd.read_csv(df2005 + '.csv')
csv2006 = pd.read_csv(df2006 + '.csv')
csv2007 = pd.read_csv(df2007 + '.csv')
csv2008 = pd.read_csv(df2008 + '.csv')
csv2009 = pd.read_csv(df2009 + '.csv')
csv2010 = pd.read_csv(df2010 + '.csv')
csv2011 = pd.read_csv(df2011 + '.csv')
csv2012 = pd.read_csv(df2012 + '.csv')
csv2013 = pd.read_csv(df2013 + '.csv')
csv2014 = pd.read_csv(df2014 + '.csv')
csv2015 = pd.read_csv(df2015 + '.csv')
csv2016 = pd.read_csv(df2016 + '.csv')
csv2017 = pd.read_csv(df2017 + '.csv')
csv2018 = pd.read_csv(df2018 + '.csv')

# %%
csv2012.columns.values[3] = "건수"
csv2012
# Out:
#         구분   죄종 발생검거      건수        date
# 0       중부   살인   발생     4.0  2012-01-01
# 1       중부   살인   검거     5.0  2012-01-01
# 2       중부   강도   발생     9.0  2012-01-01
# 3       중부   강도   검거     8.0  2012-01-01
# 4       중부   강간   발생   100.0  2012-01-01
# 5       중부   강간   검거    73.0  2012-01-01
# 6       중부   절도   발생  1497.0  2012-01-01
# 7       중부   절도   검거   421.0  2012-01-01
# 8       중부   폭력   발생  1580.0  2012-01-01
# 9       중부   폭력   검거  1361.0  2012-01-01
# 10      종로   살인   발생     2.0  2012-01-01
# 11      종로   살인   검거     1.0  2012-01-01
# 12      종로   강도   발생     5.0  2012-01-01
# 13      종로   강도   검거     3.0  2012-01-01
# 14      종로   강간   발생    93.0  2012-01-01
# 15      종로   강간   검거    77.0  2012-01-01
# 16      종로   절도   발생  1036.0  2012-01-01
# 17      종로   절도   검거   344.0  2012-01-01
# 18      종로   폭력   발생  1279.0  2012-01-01
# 19      종로   폭력   검거  1079.0  2012-01-01
# 20     남대문   살인   발생     1.0  2012-01-01
# 21     남대문   살인   검거     1.0  2012-01-01
# 22     남대문   강도   발생     5.0  2012-01-01
# 23     남대문   강도   검거     4.0  2012-01-01
# 24     남대문   강간   발생    68.0  2012-01-01
# 25     남대문   강간   검거    60.0  2012-01-01
# 26     남대문   절도   발생   892.0  2012-01-01
# 27     남대문   절도   검거   353.0  2012-01-01
# 28     남대문   폭력   발생  1116.0  2012-01-01
# 29     남대문   폭력   검거   984.0  2012-01-01
# ...    ...  ...  ...     ...         ...
# 65504  NaN  NaN  NaN     NaN  2012-01-01
# 65505  NaN  NaN  NaN     NaN  2012-01-01
# 65506  NaN  NaN  NaN     NaN  2012-01-01
# 65507  NaN  NaN  NaN     NaN  2012-01-01
# 65508  NaN  NaN  NaN     NaN  2012-01-01
# 65509  NaN  NaN  NaN     NaN  2012-01-01
# 65510  NaN  NaN  NaN     NaN  2012-01-01
# 65511  NaN  NaN  NaN     NaN  2012-01-01
# 65512  NaN  NaN  NaN     NaN  2012-01-01
# 65513  NaN  NaN  NaN     NaN  2012-01-01
# 65514  NaN  NaN  NaN     NaN  2012-01-01
# 65515  NaN  NaN  NaN     NaN  2012-01-01
# 65516  NaN  NaN  NaN     NaN  2012-01-01
# 65517  NaN  NaN  NaN     NaN  2012-01-01
# 65518  NaN  NaN  NaN     NaN  2012-01-01
# 65519  NaN  NaN  NaN     NaN  2012-01-01
# 65520  NaN  NaN  NaN     NaN  2012-01-01
# 65521  NaN  NaN  NaN     NaN  2012-01-01
# 65522  NaN  NaN  NaN     NaN  2012-01-01
# 65523  NaN  NaN  NaN     NaN  2012-01-01
# 65524  NaN  NaN  NaN     NaN  2012-01-01
# 65525  NaN  NaN  NaN     NaN  2012-01-01
# 65526  NaN  NaN  NaN     NaN  2012-01-01
# 65527  NaN  NaN  NaN     NaN  2012-01-01
# 65528  NaN  NaN  NaN     NaN  2012-01-01
# 65529  NaN  NaN  NaN     NaN  2012-01-01
# 65530  NaN  NaN  NaN     NaN  2012-01-01
# 65531  NaN  NaN  NaN     NaN  2012-01-01
# 65532  NaN  NaN  NaN     NaN  2012-01-01
# 65533  NaN  NaN  NaN     NaN  2012-01-01
#
# [65534 rows x 5 columns]

# %%
yearInter_df = pd.concat([csv2000, csv2001, csv2002, csv2003, csv2004, csv2005, csv2006, csv2007, csv2008, csv2009, csv2010, csv2011, csv2012, csv2013, csv2014, csv2015, csv2016, csv2017, csv2018], ignore_index=True, axis = 0)

# %%
yearInter_df = yearInter_df.dropna(axis=0)

# %%
yearInter_df = yearInter_df.reset_index()

# %%
# del yearInter_df['index']
# del yearInter_df['level_0']
yearInter_df.to_csv('yearInter.csv')
